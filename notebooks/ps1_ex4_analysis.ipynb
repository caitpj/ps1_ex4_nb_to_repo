# %% [markdown]
# # PS1 Exercise 4 Analysis
#
# This notebook contains the analysis and visualizations for the PS1 Exercise 4 project. The code has been modularized into functions that are imported from the `src` directory.

# %%
import sys
import os
sys.path.append(os.path.abspath('../src'))

from ps1_ex4_nb_to_repo.data import load_data, save_data
from ps1_ex4_nb_to_repo.preprocessing import clean_data, transform_data
from ps1_ex4_nb_to_repo.analysis import perform_analysis, summarize_results
from ps1_ex4_nb_to_repo.visualization import plot_data, show_results

# Load the dataset
data = load_data('path/to/dataset.csv')

# Clean the data
cleaned_data = clean_data(data)

# Transform the data
transformed_data = transform_data(cleaned_data)

# Perform analysis
analysis_results = perform_analysis(transformed_data)

# Summarize results
summary = summarize_results(analysis_results)

# Visualize the results
plot_data(transformed_data)
show_results(summary)
